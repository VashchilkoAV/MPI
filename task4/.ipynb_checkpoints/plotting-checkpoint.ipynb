# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Dynamic (N = 1000000, T = 0.000000001)

# %%
df = pd.read_csv("./result.txt", header=None, sep=" ")
df.rename(columns={0: 'Threads', 1: 'Real time', 2: 'User time'}, inplace=True)
df['Acceleration'] = df['Real time'][0] / df['Real time']
print(df)
plt.figure(figsize=(14, 10))
plt.xlabel('Threads', fontsize=20)
plt.ylabel('Acceleration', fontsize=20)
plt.grid(True)
plt.title('', fontsize=20)
plt.plot(df['Threads'], df['Acceleration'], 'ob-', label='Acceleration')
plt.legend(fontsize=20, loc='best')
plt.savefig('Acceleration_dynamic.jpg')
plt.show()
# Out:
#    Threads  Real time  User time  Acceleration
# 0        1     16.686     16.860      1.000000
# 1        2      8.615     17.173      1.936854
# 2        3      5.844     17.491      2.855236
# 3        4      4.527     18.051      3.685885
# 4        5      4.515     22.524      3.695681
# 5        6      4.409     26.361      3.784532
# 6        7      4.377     30.404      3.812200
# 7        8      4.599     36.235      3.628180

# %% [markdown]
# # Static (N = 1000000, T = 0.000000001)

# %%
df = pd.read_csv("./result2.txt", header=None, sep=" ")
df.rename(columns={0: 'Threads', 1: 'Time'}, inplace=True)
df['Acceleration'] = df['Time'][0] / df['Time']
print(df)
plt.figure(figsize=(14, 10))
plt.xlabel('Threads', fontsize=20)
plt.ylabel('Acceleration', fontsize=20)
plt.grid(True)
plt.title('', fontsize=20)
plt.plot(df['Threads'], df['Acceleration'], 'ob-', label='Acceleration')
plt.legend(fontsize=20, loc='best')
plt.savefig('Acceleration_static.jpg')
plt.show()
# Out:
#    Threads    Time  Acceleration
# 0        1  17.010      1.000000
# 1        2  10.188      1.669611
# 2        3   5.804      2.930737
# 3        4   4.520      3.763274
# 4        5   6.583      2.583928
# 5        6   5.506      3.089357
# 6        7   4.956      3.432203
# 7        8   4.579      3.714785
